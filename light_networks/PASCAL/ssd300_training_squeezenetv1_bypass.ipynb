# %%
# libraries
import os
import sys
import json
import numpy as np
import pandas as pd
sys.path.append(os.path.abspath('../../'))
sys.path.append(os.path.abspath('../../extra_files'))
import helper as hp
from imageio import imwrite, imread
from skimage.transform import resize

# %%
# File paths
data_path = '/home/aldo/Documents/data-cic/'
preprocess_path = data_path + 'preprocess_data'

# %% [markdown]
# ## Training SSD300 trained with mobilenet backbone trained

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from light_models.keras_ssd300_squeezenetv1_bypass import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

from extra_files.f1_callback import F1_callback as f1_call
# Out:
# Using TensorFlow backend.
# /home/aldo/Documents/ssd/data_generator/object_detection_2d_data_generator.py:43: UserWarning: 'BeautifulSoup' module is missing. The XML-parser will be unavailable.
#   warnings.warn("'BeautifulSoup' module is missing. The XML-parser will be unavailable.")

# %% [markdown]
# ### Parameters (original SSD300 architecture)

# %%
## Parameteres needed for ssd_300() and SSDInputEncoder()

img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [1., 1., 1.] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
divide_by_stddev = [127.5, 127.5, 127.5]
swap_channels = False # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 1 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
scales = scales_pascal
#scales = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05]
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [16, 30, 60, 100, 150, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %% [markdown]
# ## Create new model with SSD weights

# %%
# 1: Build the Keras model.

K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                divide_by_stddev=divide_by_stddev,
                swap_channels=swap_channels)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

adam = Adam(lr=0.001)
#sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 300, 300, 3)  0
# __________________________________________________________________________________________________
# identity_layer (Lambda)         (None, 300, 300, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# input_stddev_normalization (Lam (None, 300, 300, 3)  0           identity_layer[0][0]
# __________________________________________________________________________________________________
# input_mean_normalization (Lambd (None, 300, 300, 3)  0           input_stddev_normalization[0][0]
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 19, 19, 512)  722496      input_mean_normalization[0][0]
# __________________________________________________________________________________________________
# maxpool9 (MaxPooling2D)         (None, 10, 10, 512)  0           model_2[1][0]
# __________________________________________________________________________________________________
# fire10_squeeze (Conv2D)         (None, 10, 10, 64)   32832       maxpool9[0][0]
# __________________________________________________________________________________________________
# fire10_expand1 (Conv2D)         (None, 10, 10, 256)  16640       fire10_squeeze[0][0]
# __________________________________________________________________________________________________
# fire10_expand2 (Conv2D)         (None, 10, 10, 256)  147712      fire10_squeeze[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 10, 10, 512)  0           fire10_expand1[0][0]
#                                                                  fire10_expand2[0][0]
# __________________________________________________________________________________________________
# conv_pad_11_1 (ZeroPadding2D)   (None, 12, 12, 512)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv__11_1 (Conv2D)             (None, 12, 12, 256)  131072      conv_pad_11_1[0][0]
# __________________________________________________________________________________________________
# conv_11_bn_1 (BatchNormalizatio (None, 12, 12, 256)  1024        conv__11_1[0][0]
# __________________________________________________________________________________________________
# conv_11_relu_1 (Activation)     (None, 12, 12, 256)  0           conv_11_bn_1[0][0]
# __________________________________________________________________________________________________
# conv__11_2 (Conv2D)             (None, 5, 5, 512)    1179648     conv_11_relu_1[0][0]
# __________________________________________________________________________________________________
# conv_11_bn_2 (BatchNormalizatio (None, 5, 5, 512)    2048        conv__11_2[0][0]
# __________________________________________________________________________________________________
# conv_11_relu_2 (Activation)     (None, 5, 5, 512)    0           conv_11_bn_2[0][0]
# __________________________________________________________________________________________________
# conv_pad_12_1 (ZeroPadding2D)   (None, 7, 7, 512)    0           conv_11_relu_2[0][0]
# __________________________________________________________________________________________________
# conv__12_1 (Conv2D)             (None, 7, 7, 128)    65536       conv_pad_12_1[0][0]
# __________________________________________________________________________________________________
# conv_12_bn_1 (BatchNormalizatio (None, 7, 7, 128)    512         conv__12_1[0][0]
# __________________________________________________________________________________________________
# conv_12_relu_1 (Activation)     (None, 7, 7, 128)    0           conv_12_bn_1[0][0]
# __________________________________________________________________________________________________
# conv__12_2 (Conv2D)             (None, 3, 3, 256)    294912      conv_12_relu_1[0][0]
# __________________________________________________________________________________________________
# conv_12_bn_2 (BatchNormalizatio (None, 3, 3, 256)    1024        conv__12_2[0][0]
# __________________________________________________________________________________________________
# conv_12_relu_2 (Activation)     (None, 3, 3, 256)    0           conv_12_bn_2[0][0]
# __________________________________________________________________________________________________
# conv_pad_13_1 (ZeroPadding2D)   (None, 5, 5, 256)    0           conv_12_relu_2[0][0]
# __________________________________________________________________________________________________
# conv__13_1 (Conv2D)             (None, 5, 5, 128)    32768       conv_pad_13_1[0][0]
# __________________________________________________________________________________________________
# conv_13_bn_1 (BatchNormalizatio (None, 5, 5, 128)    512         conv__13_1[0][0]
# __________________________________________________________________________________________________
# conv_13_relu_1 (Activation)     (None, 5, 5, 128)    0           conv_13_bn_1[0][0]
# __________________________________________________________________________________________________
# conv__13_2 (Conv2D)             (None, 2, 2, 256)    294912      conv_13_relu_1[0][0]
# __________________________________________________________________________________________________
# conv_13_bn_2 (BatchNormalizatio (None, 2, 2, 256)    1024        conv__13_2[0][0]
# __________________________________________________________________________________________________
# conv_13_relu_2 (Activation)     (None, 2, 2, 256)    0           conv_13_bn_2[0][0]
# __________________________________________________________________________________________________
# conv_pad_14_1 (ZeroPadding2D)   (None, 4, 4, 256)    0           conv_13_relu_2[0][0]
# __________________________________________________________________________________________________
# conv__14_1 (Conv2D)             (None, 4, 4, 64)     16384       conv_pad_14_1[0][0]
# __________________________________________________________________________________________________
# conv_14_bn_1 (BatchNormalizatio (None, 4, 4, 64)     256         conv__14_1[0][0]
# __________________________________________________________________________________________________
# conv_14_relu_1 (Activation)     (None, 4, 4, 64)     0           conv_14_bn_1[0][0]
# __________________________________________________________________________________________________
# conv__14_2 (Conv2D)             (None, 1, 1, 128)    73728       conv_14_relu_1[0][0]
# __________________________________________________________________________________________________
# conv9_mbox_conf (Conv2D)        (None, 19, 19, 8)    36872       model_2[1][0]
# __________________________________________________________________________________________________
# conv10_mbox_conf (Conv2D)       (None, 10, 10, 12)   55308       concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv11_2_mbox_conf (Conv2D)     (None, 5, 5, 12)     55308       conv__11_2[0][0]
# __________________________________________________________________________________________________
# conv12_2_mbox_conf (Conv2D)     (None, 3, 3, 12)     27660       conv__12_2[0][0]
# __________________________________________________________________________________________________
# conv13_2_mbox_conf (Conv2D)     (None, 2, 2, 8)      18440       conv__13_2[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_conf (Conv2D)     (None, 1, 1, 8)      9224        conv__14_2[0][0]
# __________________________________________________________________________________________________
# conv9_mbox_loc (Conv2D)         (None, 19, 19, 16)   73744       model_2[1][0]
# __________________________________________________________________________________________________
# conv10_mbox_loc (Conv2D)        (None, 10, 10, 24)   110616      concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv11_2_mbox_loc (Conv2D)      (None, 5, 5, 24)     110616      conv__11_2[0][0]
# __________________________________________________________________________________________________
# conv12_2_mbox_loc (Conv2D)      (None, 3, 3, 24)     55320       conv__12_2[0][0]
# __________________________________________________________________________________________________
# conv13_2_mbox_loc (Conv2D)      (None, 2, 2, 16)     36880       conv__13_2[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_loc (Conv2D)      (None, 1, 1, 16)     18448       conv__14_2[0][0]
# __________________________________________________________________________________________________
# conv9_mbox_conf_reshape (Reshap (None, 1444, 2)      0           conv9_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv10_mbox_conf_reshape (Resha (None, 600, 2)       0           conv10_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv11_2_mbox_conf_reshape (Res (None, 150, 2)       0           conv11_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv12_2_mbox_conf_reshape (Res (None, 54, 2)        0           conv12_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv13_2_mbox_conf_reshape (Res (None, 16, 2)        0           conv13_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_conf_reshape (Res (None, 4, 2)         0           conv14_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv9_mbox_priorbox (AnchorBoxe (None, 19, 19, 4, 8) 0           conv9_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv10_mbox_priorbox (AnchorBox (None, 10, 10, 6, 8) 0           conv10_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv11_2_mbox_priorbox (AnchorB (None, 5, 5, 6, 8)   0           conv11_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv12_2_mbox_priorbox (AnchorB (None, 3, 3, 6, 8)   0           conv12_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv13_2_mbox_priorbox (AnchorB (None, 2, 2, 4, 8)   0           conv13_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_priorbox (AnchorB (None, 1, 1, 4, 8)   0           conv14_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# mbox_conf (Concatenate)         (None, 2268, 2)      0           conv9_mbox_conf_reshape[0][0]
#                                                                  conv10_mbox_conf_reshape[0][0]
#                                                                  conv11_2_mbox_conf_reshape[0][0]
#                                                                  conv12_2_mbox_conf_reshape[0][0]
#                                                                  conv13_2_mbox_conf_reshape[0][0]
#                                                                  conv14_2_mbox_conf_reshape[0][0]
# __________________________________________________________________________________________________
# conv9_mbox_loc_reshape (Reshape (None, 1444, 4)      0           conv9_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv10_mbox_loc_reshape (Reshap (None, 600, 4)       0           conv10_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv11_2_mbox_loc_reshape (Resh (None, 150, 4)       0           conv11_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv12_2_mbox_loc_reshape (Resh (None, 54, 4)        0           conv12_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv13_2_mbox_loc_reshape (Resh (None, 16, 4)        0           conv13_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_loc_reshape (Resh (None, 4, 4)         0           conv14_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv9_mbox_priorbox_reshape (Re (None, 1444, 8)      0           conv9_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv10_mbox_priorbox_reshape (R (None, 600, 8)       0           conv10_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv11_2_mbox_priorbox_reshape  (None, 150, 8)       0           conv11_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv12_2_mbox_priorbox_reshape  (None, 54, 8)        0           conv12_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv13_2_mbox_priorbox_reshape  (None, 16, 8)        0           conv13_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_priorbox_reshape  (None, 4, 8)         0           conv14_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# mbox_conf_softmax (Activation)  (None, 2268, 2)      0           mbox_conf[0][0]
# __________________________________________________________________________________________________
# mbox_loc (Concatenate)          (None, 2268, 4)      0           conv9_mbox_loc_reshape[0][0]
#                                                                  conv10_mbox_loc_reshape[0][0]
#                                                                  conv11_2_mbox_loc_reshape[0][0]
#                                                                  conv12_2_mbox_loc_reshape[0][0]
#                                                                  conv13_2_mbox_loc_reshape[0][0]
#                                                                  conv14_2_mbox_loc_reshape[0][0]
# __________________________________________________________________________________________________
# mbox_priorbox (Concatenate)     (None, 2268, 8)      0           conv9_mbox_priorbox_reshape[0][0]
#                                                                  conv10_mbox_priorbox_reshape[0][0
#                                                                  conv11_2_mbox_priorbox_reshape[0]
#                                                                  conv12_2_mbox_priorbox_reshape[0]
#                                                                  conv13_2_mbox_priorbox_reshape[0]
#                                                                  conv14_2_mbox_priorbox_reshape[0]
# __________________________________________________________________________________________________
# predictions (Concatenate)       (None, 2268, 14)     0           mbox_conf_softmax[0][0]
#                                                                  mbox_loc[0][0]
#                                                                  mbox_priorbox[0][0]
# ==================================================================================================
# Total params: 3,623,476
# Trainable params: 3,620,276
# Non-trainable params: 3,200
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data generator for the training

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
images_dir = data_path + 'PASCAL'
#images_dir = data_path + 'COCO'

# Ground truth
#train_labels_filename = preprocess_path + '/PASCAL_train.csv'
train_labels_filename = preprocess_path + '/PASCAL_train_val.csv'
val_labels_filename   = preprocess_path + '/PASCAL_val.csv'

train_dataset.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset.parse_csv(#images_dir=images_dir,
                      data_path + 'PASCAL',
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Loading images into memory: 100%|██████████| 6469/6469 [00:29<00:00, 220.88it/s]
# Loading images into memory: 100%|██████████| 1025/1025 [00:04<00:00, 216.01it/s]
# Number of images in the training dataset:	  6469
# Number of images in the validation dataset:	  1025

# %%
# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv9_mbox_conf').output_shape[1:3],
                   model.get_layer('conv10_mbox_conf').output_shape[1:3],
                   model.get_layer('conv11_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv12_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv13_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv14_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  6469
# Number of images in the validation dataset:	  1025

# %% [markdown]
# ## Remaining training parameters

# %%
# Define a learning rate schedule.
def lr_schedule(epoch):
    if epoch < 60:
        return 0.0001
    elif epoch < 70:
        return 0.00001
    else:
        return 0.000001

# %%
K.clear_session() # Clear previous models from memory.
model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                divide_by_stddev=divide_by_stddev,
                swap_channels=swap_channels)

adam = Adam(lr=0.001)
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
model.compile(optimizer=adam, loss=ssd_loss.compute_loss)
    
# Define model callbacks.
main_path = '/home/aldo/Documents/'
# TODO: Set the filepath under which you want to save the model.

csv_logger = CSVLogger(filename=main_path + 'data-cic/history/light_models/PASCAL/squeezenet_v1_bypass.csv',
                           separator=',',
                           append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule, verbose=1)


callbacks = [csv_logger,
             learning_rate_scheduler]
    
initial_epoch   = 0
final_epoch     = 80
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                                  steps_per_epoch=steps_per_epoch,
                                  epochs=final_epoch,
                                  callbacks=callbacks,
                                  initial_epoch=initial_epoch)
    
model.save(main_path + 'weights/light_models/PASCAL/squeezenet_v1_bypass.h5')
# Out:
# Epoch 1/80
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 670s 670ms/step - loss: 5.3169
# Epoch 2/80
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 583s 583ms/step - loss: 4.9028
# Epoch 3/80
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 560s 560ms/step - loss: 4.7268
# Epoch 4/80
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 560s 560ms/step - loss: 4.5795
# Epoch 5/80
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 560s 560ms/step - loss: 4.4571
# Epoch 6/80
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 558s 558ms/step - loss: 4.3837
# Epoch 7/80
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 560s 560ms/step - loss: 4.3303
# Epoch 8/80
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 559s 559ms/step - loss: 4.2809
# Epoch 9/80
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 559s 559ms/step - loss: 4.2325
# Epoch 10/80
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 560s 560ms/step - loss: 4.2050
# Epoch 11/80
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 555s 555ms/step - loss: 4.1666
# Epoch 12/80
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 558s 558ms/step - loss: 4.1380
# Epoch 13/80
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 558s 558ms/step - loss: 4.1084
# Epoch 14/80
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 561s 561ms/step - loss: 4.0642
# Epoch 15/80
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 558s 558ms/step - loss: 4.0460
# Epoch 16/80
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 558s 558ms/step - loss: 4.0280
# Epoch 17/80
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 561s 561ms/step - loss: 4.0006
# Epoch 18/80
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 559s 559ms/step - loss: 3.9693
# Epoch 19/80
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 558s 558ms/step - loss: 3.9513
# Epoch 20/80
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 558s 558ms/step - loss: 3.9436
# Epoch 21/80
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 560s 560ms/step - loss: 3.9088
# Epoch 22/80
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 560s 560ms/step - loss: 3.8819
# Epoch 23/80
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 559s 559ms/step - loss: 3.8660
# Epoch 24/80
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 557s 557ms/step - loss: 3.8334
# Epoch 25/80
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 557s 557ms/step - loss: 3.8173
# Epoch 26/80
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 558s 558ms/step - loss: 3.8181
# Epoch 27/80
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 557s 557ms/step - loss: 3.7948
# Epoch 28/80
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 556s 556ms/step - loss: 3.7911
# Epoch 29/80
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 561s 561ms/step - loss: 3.7601
# Epoch 30/80
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 559s 559ms/step - loss: 3.7578
# Epoch 31/80
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 557s 557ms/step - loss: 3.7304
# Epoch 32/80
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 558s 558ms/step - loss: 3.7230
# Epoch 33/80
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 558s 558ms/step - loss: 3.6898
# Epoch 34/80
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 559s 559ms/step - loss: 3.7118
# Epoch 35/80
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 558s 558ms/step - loss: 3.6711
# Epoch 36/80
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 560s 560ms/step - loss: 3.6664
# Epoch 37/80
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 559s 559ms/step - loss: 3.6616
# Epoch 38/80
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 560s 560ms/step - loss: 3.6411
# Epoch 39/80
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 560s 560ms/step - loss: 3.6249
# Epoch 40/80
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 557s 557ms/step - loss: 3.6151
# Epoch 41/80
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 615s 615ms/step - loss: 3.5980
# Epoch 42/80
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 622s 622ms/step - loss: 3.6068
# Epoch 43/80
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 555s 555ms/step - loss: 3.5787
# Epoch 44/80
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 553s 553ms/step - loss: 3.5570
# Epoch 45/80
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 554s 554ms/step - loss: 3.5536
# Epoch 46/80
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 557s 557ms/step - loss: 3.5607
# Epoch 47/80
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 557s 557ms/step - loss: 3.5307
# Epoch 48/80
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 553s 553ms/step - loss: 3.5129
# Epoch 49/80
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 555s 555ms/step - loss: 3.5333
# Epoch 50/80
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 561s 561ms/step - loss: 3.5098
# Epoch 51/80
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 557s 557ms/step - loss: 3.5124
# Epoch 52/80
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 553s 553ms/step - loss: 3.5029
# Epoch 53/80
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 557s 557ms/step - loss: 3.4931
# Epoch 54/80
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 564s 564ms/step - loss: 3.4740
# Epoch 55/80
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 553s 553ms/step - loss: 3.4863
# Epoch 56/80
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 554s 554ms/step - loss: 3.4658
# Epoch 57/80
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 554s 554ms/step - loss: 3.4554
# Epoch 58/80
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 556s 556ms/step - loss: 3.4491
# Epoch 59/80
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 555s 555ms/step - loss: 3.4428
# Epoch 60/80
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 556s 556ms/step - loss: 3.4408
# Epoch 61/80
#
# Epoch 00061: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 556s 556ms/step - loss: 3.3469
# Epoch 62/80
#
# Epoch 00062: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 605s 605ms/step - loss: 3.3223
# Epoch 63/80
#
# Epoch 00063: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 572s 572ms/step - loss: 3.3192
# Epoch 64/80
#
# Epoch 00064: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 552s 552ms/step - loss: 3.3174
# Epoch 65/80
#
# Epoch 00065: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 554s 554ms/step - loss: 3.3126
# Epoch 66/80
#
# Epoch 00066: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 553s 553ms/step - loss: 3.3074
# Epoch 67/80
#
# Epoch 00067: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 551s 551ms/step - loss: 3.3084
# Epoch 68/80
#
# Epoch 00068: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 551s 551ms/step - loss: 3.3047
# Epoch 69/80
#
# Epoch 00069: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 554s 554ms/step - loss: 3.3064
# Epoch 70/80
#
# Epoch 00070: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 554s 554ms/step - loss: 3.2873
# Epoch 71/80
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1e-06.
# 1000/1000 [==============================] - 551s 551ms/step - loss: 3.2906
# Epoch 72/80
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1e-06.
# 1000/1000 [==============================] - 548s 548ms/step - loss: 3.2750
# Epoch 73/80
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1e-06.
# 1000/1000 [==============================] - 551s 551ms/step - loss: 3.2656
# Epoch 74/80
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1e-06.
# 1000/1000 [==============================] - 551s 551ms/step - loss: 3.2768
# Epoch 75/80
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1e-06.
# 1000/1000 [==============================] - 548s 548ms/step - loss: 3.2757
# Epoch 76/80
#
# Epoch 00076: LearningRateScheduler setting learning rate to 1e-06.
# 1000/1000 [==============================] - 552s 552ms/step - loss: 3.2777
# Epoch 77/80
#
# Epoch 00077: LearningRateScheduler setting learning rate to 1e-06.
# 1000/1000 [==============================] - 553s 553ms/step - loss: 3.2914
# Epoch 78/80
#
# Epoch 00078: LearningRateScheduler setting learning rate to 1e-06.
# 1000/1000 [==============================] - 572s 572ms/step - loss: 3.2671
# Epoch 79/80
#
# Epoch 00079: LearningRateScheduler setting learning rate to 1e-06.
# 1000/1000 [==============================] - 556s 556ms/step - loss: 3.2804
# Epoch 80/80
#
# Epoch 00080: LearningRateScheduler setting learning rate to 1e-06.
# 1000/1000 [==============================] - 551s 551ms/step - loss: 3.2659
