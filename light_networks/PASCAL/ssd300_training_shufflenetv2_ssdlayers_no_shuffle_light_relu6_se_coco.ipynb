# %%
# libraries
import os
import sys
import json
import numpy as np
import pandas as pd
sys.path.append(os.path.abspath('../../'))
sys.path.append(os.path.abspath('../../extra_files'))
import helper as hp
from imageio import imwrite, imread
from skimage.transform import resize

# %%
# File paths
data_path = '/home/aldo/Documents/data-cic/'
preprocess_path = data_path + 'preprocess_data'

# %% [markdown]
# ## Training SSD300 trained with mobilenet backbone trained

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from light_models.keras_ssd300_shufflenetv2_ssdlayers_light_relu6_se_no_shuffle import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

from extra_files.f1_callback import F1_callback as f1_call
# Out:
# Using TensorFlow backend.
# /home/aldo/Documents/ssd/data_generator/object_detection_2d_data_generator.py:43: UserWarning: 'BeautifulSoup' module is missing. The XML-parser will be unavailable.
#   warnings.warn("'BeautifulSoup' module is missing. The XML-parser will be unavailable.")

# %% [markdown]
# ### Parameters (original SSD300 architecture)

# %%
## Parameteres needed for ssd_300() and SSDInputEncoder()

img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [1., 1., 1.] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
divide_by_stddev = [127.5, 127.5, 127.5]
swap_channels = False # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 1 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
scales_pascal = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the COCO datasets
scales = scales_pascal
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [16, 30, 60, 100, 150, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %%
import tensorflow as tf

run_meta = tf.RunMetadata()
with tf.Session(graph=tf.Graph()) as sess:
    K.set_session(sess)
    model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                input_tensor=tf.placeholder('float32', shape=(1,300,300,3)),
                mode='inference',
                scale_factor=1.5,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                divide_by_stddev=divide_by_stddev,
                swap_channels=swap_channels)
    opts = tf.profiler.ProfileOptionBuilder.float_operation()    
    flops = tf.profiler.profile(sess.graph, run_meta=run_meta, cmd='op', options=opts)

    opts = tf.profiler.ProfileOptionBuilder.trainable_variables_parameter()    
    params = tf.profiler.profile(sess.graph, run_meta=run_meta, cmd='op', options=opts)

# %%
# Factor 1.5
print("{:,} --- {:,}".format(flops.total_float_ops/2, params.total_parameters))
# Out:
# 596,843,577.5 --- 5,384,276

# %% [markdown]
# ## Create new model with SSD weights

# %%
# 1: Build the Keras model.

K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                scale_factor=1.5,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                divide_by_stddev=divide_by_stddev,
                swap_channels=swap_channels)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

adam = Adam(lr=0.001)
#sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
model.summary()

# %% [markdown]
# ## Data generator for the training

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
#images_dir = data_path + 'PASCAL'
images_dir = data_path + 'COCO'

# Ground truth
#train_labels_filename = preprocess_path + '/PASCAL_train.csv'
#train_labels_filename = preprocess_path + '/PASCAL_train_val.csv'
val_labels_filename   = preprocess_path + '/PASCAL_val.csv'
train_labels_filename = preprocess_path + '/coco.csv'


train_dataset.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset.parse_csv(#images_dir=images_dir,
                      data_path + 'PASCAL',
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))

# %%
# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv13_mbox_conf').output_shape[1:3],
                   model.get_layer('conv18_mbox_conf').output_shape[1:3],
                   model.get_layer('conv19_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv20_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv21_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv22_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))

# %% [markdown]
# ## Remaining training parameters

# %%
# Define a learning rate schedule.
def lr_schedule(epoch):
    if epoch < 160:
        return 0.001
    elif epoch < 200:
        return 0.0001
    else:
        return 0.00001

# %%
scale_factors = [1.5]

for factor in scale_factors:
    # 1: Build the Keras model.
    K.clear_session() # Clear previous models from memory.

    print('TRAINING MODEL WITH FACTOR:', factor)
    
    model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                scale_factor=factor,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                divide_by_stddev=divide_by_stddev,
                swap_channels=swap_channels)

    adam = Adam(lr=0.001)
    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
    model.compile(optimizer=adam, loss=ssd_loss.compute_loss)
    
    # Define model callbacks.
    main_path = '/home/aldo/Documents/'
    # TODO: Set the filepath under which you want to save the model.

    csv_logger = CSVLogger(filename=main_path + 'data-cic/history/light_models/PASCAL/shufflenet_v2_ssdlayers_no_shuffle_light_relu6_coco_factor_' + 
                           str(factor) + '.csv',
                           separator=',',
                           append=True)

    learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule, verbose=1)


    callbacks = [csv_logger,
                 learning_rate_scheduler]
    
    initial_epoch   = 0
    final_epoch     = 240
    steps_per_epoch = 1000

    history = model.fit_generator(generator=train_generator,
                                  steps_per_epoch=steps_per_epoch,
                                  epochs=final_epoch,
                                  callbacks=callbacks,
                                  initial_epoch=initial_epoch)
    
    model.save(main_path + 'weights/light_models/PASCAL/shufflenet_v2_ssdlayers_no_shuffle_light_relu6_coco_factor_' + str(factor) + '.h5')
# Out:
# TRAINING MODEL WITH FACTOR: 1.5
# Epoch 1/240
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 932s 932ms/step - loss: 6.3625
# Epoch 2/240
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 926s 926ms/step - loss: 5.7406
# Epoch 3/240
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 929s 929ms/step - loss: 5.4607
# Epoch 4/240
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 921s 921ms/step - loss: 5.3657
# Epoch 5/240
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 918s 918ms/step - loss: 5.2738
# Epoch 6/240
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 921s 921ms/step - loss: 5.2167
# Epoch 7/240
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 920s 920ms/step - loss: 5.1355
# Epoch 8/240
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 916s 916ms/step - loss: 5.0939
# Epoch 9/240
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 917s 917ms/step - loss: 5.0316
# Epoch 10/240
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 912s 912ms/step - loss: 4.9995
# Epoch 11/240
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 912s 912ms/step - loss: 4.9542
# Epoch 12/240
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 915s 915ms/step - loss: 4
LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 952s 952ms/step - loss: 4.0424
# Epoch 138/240
#
# Epoch 00138: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 943s 943ms/step - loss: 4.0617
# Epoch 139/240
#
# Epoch 00139: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 941s 941ms/step - loss: 4.0361
# Epoch 140/240
#
# Epoch 00140: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 955s 955ms/step - loss: 4.0536
# Epoch 141/240
#
# Epoch 00141: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 943s 943ms/step - loss: 4.0437
# Epoch 142/240
#
# Epoch 00142: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 948s 948ms/step - loss: 4.0530
# Epoch 143/240
#
# Epoch 00143: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 949s 949ms/step - loss: 4.0302
# Epoch 144/240
#
# Epoch 00144: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 975s 975ms/step - loss: 4.0538
# Epoch 145/240
#
# Epoch 00145: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1001s 1s/step - loss: 4.0494
# Epoch 146/240
#
# Epoch 00146: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1005s 1s/step - loss: 4.0310
# Epoch 147/240
#
# Epoch 00147: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 980s 980ms/step - loss: 4.0319
# Epoch 148/240
#
# Epoch 00148: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 990s 990ms/step - loss: 4.0722
# Epoch 149/240
#
# Epoch 00149: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1069s 1s/step - loss: 4.0568
# Epoch 150/240
#
# Epoch 00150: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1031s 1s/step - loss: 4.0454
# Epoch 151/240
#
# Epoch 00151: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1061s 1s/step - loss: 4.0428
# Epoch 152/240
#
# Epoch 00152: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1050s 1s/step - loss: 4.0336
# Epoch 153/240
#
# Epoch 00153: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 1041s 1s/step - loss: 4.0370
# Epoch 154/240
#
# Epoch 00154: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 992s 992ms/step - loss: 4.0288
# Epoch 155/240
#
# Epoch 00155: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 917s 917ms/step - loss: 4.0294
# Epoch 156/240
#
# Epoch 00156: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 926s 926ms/step - loss: 4.0416
# Epoch 157/240
#
# Epoch 00157: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 928s 928ms/step - loss: 4.0360
# Epoch 158/240
#
# Epoch 00158: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 918s 918ms/step - loss: 4.0192
# Epoch 159/240
#
# Epoch 00159: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 957s 957ms/step - loss: 4.0174
# Epoch 160/240
#
# Epoch 00160: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 938s 938ms/step - loss: 4.0235
# Epoch 161/240
#
# Epoch 00161: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 922s 922ms/step - loss: 3.9666
# Epoch 162/240
#
# Epoch 00162: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 926s 926ms/step - loss: 3.9182
# Epoch 163/240
#
# Epoch 00163: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 922s 922ms/step - loss: 3.9144
# Epoch 164/240
#
# Epoch 00164: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 917s 917ms/step - loss: 3.9182
# Epoch 165/240
#
# Epoch 00165: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 913s 913ms/step - loss: 3.9131
# Epoch 166/240
#
# Epoch 00166: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 921s 921ms/step - loss: 3.9075
# Epoch 167/240
#
# Epoch 00167: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 920s 920ms/step - loss: 3.8986
# Epoch 168/240
#
# Epoch 00168: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 918s 918ms/step - loss: 3.8808
# Epoch 169/240
#
# Epoch 00169: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 919s 919ms/step - loss: 3.9051
# Epoch 170/240
#
# Epoch 00170: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 920s 920ms/step - loss: 3.8876
# Epoch 171/240
#
# Epoch 00171: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 918s 918ms/step - loss: 3.8729
# Epoch 172/240
#
# Epoch 00172: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 3.9098
# Epoch 173/240
#
# Epoch 00173: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 918s 918ms/step - loss: 3.8732
# Epoch 174/240
#
# Epoch 00174: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 3.8803
# Epoch 175/240
#
# Epoch 00175: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 933s 933ms/step - loss: 3.8841
# Epoch 176/240
#
# Epoch 00176: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 940s 940ms/step - loss: 3.8894
# Epoch 177/240
#
# Epoch 00177: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 922s 922ms/step - loss: 3.8942
# Epoch 178/240
#
# Epoch 00178: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 917s 917ms/step - loss: 3.8795
# Epoch 179/240
#
# Epoch 00179: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 951s 951ms/step - loss: 3.8872
# Epoch 180/240
#
# Epoch 00180: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 926s 926ms/step - loss: 3.8803
# Epoch 181/240
#
# Epoch 00181: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 908s 908ms/step - loss: 3.8719
# Epoch 182/240
#
# Epoch 00182: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 928s 928ms/step - loss: 3.8822
# Epoch 183/240
#
# Epoch 00183: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 921s 921ms/step - loss: 3.8709
# Epoch 184/240
#
# Epoch 00184: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 928s 928ms/step - loss: 3.8735
# Epoch 185/240
#
# Epoch 00185: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 955s 955ms/step - loss: 3.8602
# Epoch 186/240
#
# Epoch 00186: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 969s 969ms/step - loss: 3.8697
# Epoch 187/240
#
# Epoch 00187: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 972s 972ms/step - loss: 3.8707
# Epoch 188/240
#
# Epoch 00188: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 965s 965ms/step - loss: 3.8692
# Epoch 189/240
#
# Epoch 00189: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 962s 962ms/step - loss: 3.8789
# Epoch 190/240
#
# Epoch 00190: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 940s 940ms/step - loss: 3.8497
# Epoch 191/240
#
# Epoch 00191: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 933s 933ms/step - loss: 3.8692
# Epoch 192/240
#
# Epoch 00192: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 932s 932ms/step - loss: 3.8680
# Epoch 193/240
#
# Epoch 00193: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 916s 916ms/step - loss: 3.8694
# Epoch 194/240
#
# Epoch 00194: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 922s 922ms/step - loss: 3.8732
# Epoch 195/240
#
# Epoch 00195: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 976s 976ms/step - loss: 3.8247
# Epoch 196/240
#
# Epoch 00196: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 937s 937ms/step - loss: 3.8746
# Epoch 197/240
#
# Epoch 00197: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 3.8734
# Epoch 198/240
#
# Epoch 00198: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 913s 913ms/step - loss: 3.8827
# Epoch 199/240
#
# Epoch 00199: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 3.8439
# Epoch 200/240
#
# Epoch 00200: LearningRateScheduler setting learning rate to 0.0001.
# 1000/1000 [==============================] - 918s 918ms/step - loss: 3.8721
# Epoch 201/240
#
# Epoch 00201: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 3.8582
# Epoch 202/240
#
# Epoch 00202: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 909s 909ms/step - loss: 3.8482
# Epoch 203/240
#
# Epoch 00203: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 917s 917ms/step - loss: 3.8542
# Epoch 204/240
#
# Epoch 00204: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 910s 910ms/step - loss: 3.8398
# Epoch 205/240
#
# Epoch 00205: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 3.8416
# Epoch 206/240
#
# Epoch 00206: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 915s 915ms/step - loss: 3.8628
# Epoch 207/240
#
# Epoch 00207: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 913s 913ms/step - loss: 3.8239
# Epoch 208/240
#
# Epoch 00208: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 913s 913ms/step - loss: 3.8372
# Epoch 209/240
#
# Epoch 00209: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 3.8469
# Epoch 210/240
#
# Epoch 00210: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 3.8492
# Epoch 211/240
#
# Epoch 00211: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 915s 915ms/step - loss: 3.8556
# Epoch 212/240
#
# Epoch 00212: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 913s 913ms/step - loss: 3.8684
# Epoch 213/240
#
# Epoch 00213: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 3.8441
# Epoch 214/240
#
# Epoch 00214: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 3.8495
# Epoch 215/240
#
# Epoch 00215: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 907s 907ms/step - loss: 3.8422
# Epoch 216/240
#
# Epoch 00216: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 3.8707
# Epoch 217/240
#
# Epoch 00217: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 3.8429
# Epoch 218/240
#
# Epoch 00218: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 3.8597
# Epoch 219/240
#
# Epoch 00219: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 3.8090
# Epoch 220/240
#
# Epoch 00220: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 3.8512
# Epoch 221/240
#
# Epoch 00221: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 3.8653
# Epoch 222/240
#
# Epoch 00222: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 910s 910ms/step - loss: 3.8444
# Epoch 223/240
#
# Epoch 00223: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 912s 912ms/step - loss: 3.8517
# Epoch 224/240
#
# Epoch 00224: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 913s 913ms/step - loss: 3.8464
# Epoch 225/240
#
# Epoch 00225: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 3.8406
# Epoch 226/240
#
# Epoch 00226: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 910s 910ms/step - loss: 3.8323
# Epoch 227/240
#
# Epoch 00227: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 916s 916ms/step - loss: 3.8434
# Epoch 228/240
#
# Epoch 00228: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 912s 912ms/step - loss: 3.8512
# Epoch 229/240
#
# Epoch 00229: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 912s 912ms/step - loss: 3.8582
# Epoch 230/240
#
# Epoch 00230: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 908s 908ms/step - loss: 3.8212
# Epoch 231/240
#
# Epoch 00231: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 3.8491
# Epoch 232/240
#
# Epoch 00232: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 914s 914ms/step - loss: 3.8469
# Epoch 233/240
#
# Epoch 00233: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 3.8405
# Epoch 234/240
#
# Epoch 00234: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 917s 917ms/step - loss: 3.8577
# Epoch 235/240
#
# Epoch 00235: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 3.8540
# Epoch 236/240
#
# Epoch 00236: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 910s 910ms/step - loss: 3.8348
# Epoch 237/240
#
# Epoch 00237: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 913s 913ms/step - loss: 3.8355
# Epoch 238/240
#
# Epoch 00238: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 917s 917ms/step - loss: 3.8488
# Epoch 239/240
#
# Epoch 00239: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 916s 916ms/step - loss: 3.8551
# Epoch 240/240
#
# Epoch 00240: LearningRateScheduler setting learning rate to 1e-05.
# 1000/1000 [==============================] - 911s 911ms/step - loss: 3.8485

# %%
2.78
